# %%
import pandas as pd
import numpy as  np
data=pd.read_excel("slr09.xls")
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data = scaler.fit_transform(data)

# %%
x=data[:,0]
y=data[:,1]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.1,random_state=5)

# %%
m_0=1 
c_0 =-1
eta = 0.1
del_m = 1
del_c = 1
max_iters = 10000
iters = 0
mine=[]
avge=[]
def deriv(m,c,x,y):
    return -1*(y-m*x-c)*x,-1*(y-m*x-c)
while iters<max_iters:
    
    for i in range(len(xtrain)):
        prev_m = m_0
        prev_c = c_0
        if iters==999:
            mine.append(((ytrain[i]-m_0*xtrain[i]-c_0)**2)/2)
            avge.append((ytrain[i]-m_0*xtrain[i]-c_0))
        
        del_m,del_c = deriv(prev_m,prev_c,xtrain[i],ytrain[i])
        del_m = -eta *del_m
        del_c = -eta *del_c
        m_0 = m_0+del_m
        c_0 = c_0+del_c
      
    iters+=1
    print("Iteration",iters,"\nmvalue is",m_0,"\nc value is",c_0)
print("The local minimum occurs at",m_0,c_0)
# Out:
# Iteration 1
# mvalue is -0.525940652047949
# c value is -0.19894732235379564
# Iteration 2
# mvalue is -0.5783469982477564
# c value is -0.1906809550048831
# Iteration 3
# mvalue is -0.5804212519544907
# c value is -0.19111963784070785
# Iteration 4
# mvalue is -0.5805142726030998
# c value is -0.19116575699451524
# Iteration 5
# mvalue is -0.5805188212711501
# c value is -0.191168818201643
# Iteration 6
# mvalue is -0.5805190551925594
# c value is -0.19116899815620397
# Iteration 7
# mvalue is -0.5805190675435314
# c value is -0.1911690082564631
# Iteration 8
# mvalue is -0.5805190682041963
# c value is -0.1911690088122334
# Iteration 9
# mvalue is -0.5805190682397569
# c value is -0.19116900884254398
# Iteration 10
# mvalue is -0.5805190682416767
# c value is -0.19116900884419036
# Iteration 11
# mvalue is -0.5805190682417803
# c value is -0.19116900884427956
# Iteration 12
# mvalue is -0.5805190682417859
# c value is -0.1911690088442844
# Iteration 13
# ...

# %%
import math
print("mse of train data "+str(sum(mine)/len(xtrain)))
print("rse of train data "+str(math.sqrt(sum(mine)/len(xtrain))))
print("ase of train data "+str(sum(avge)/len(xtrain)))
# Out:
# mse of train data 0.4933299928216281
# rse of train data 0.7023745388477775
# ase of train data -3.700743415417188e-17

# %%
mine=[]
avge=[]
for j in range(len(xtest)):
        mine.append(((ytest[j]-m_0*xtest[j]-c_0)**2)/2)
        avge.append((ytest[j]-m_0*xtest[j]-c_0))

# %%
import math
print("mse of train data "+str(sum(mine)/len(xtest)))
print("rse of train data "+str(math.sqrt(sum(mine)/len(xtest))))
print("ase of train data "+str(sum(avge)/len(xtest)))
# Out:
# mse of train data 0.8815599627900337
# rse of train data 0.9389142467712553
# ase of train data 1.1898881485601365
