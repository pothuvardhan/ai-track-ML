# %%
import pandas as pd

data = pd.read_excel('Load Data in kW.xlsx')
data.head()
data.shape
data.head()
# Out:
#          Date      Time   Load (kW)
# 0  01.09.2018  00:00:00  5551.82208
# 1         NaN  01:00:00  4983.17184
# 2         NaN  02:00:00  4888.39680
# 3         NaN  03:00:00  5072.95872
# 4         NaN  04:00:00  5196.25980

# %%
day_1 = data.iloc[0:-24, 2]
day_2 = data.iloc[24:, 2]
print(day_1.shape)
print(day_2.shape)
# Out:
# (2160,)
# (2160,)

# %%
day_2 = day_2.reset_index()
day_2 = day_2['Load (kW)']

# %%
df = pd.concat([day_1, day_2], axis = 1)
df.shape
# Out:
# (2160, 2)

# %%
df.columns = ['Day_1', 'Day_2']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
normalized_df = scaler.fit_transform(df)
normalized_df[:,0]
# Out:
# array([-0.45496731, -0.98830043, -1.07718928, ...,  1.01199118,
#         0.14357047, -0.35540594])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(normalized_df[:,0],normalized_df[:,1], test_size = 0.10, random_state = 42)

# %%
m = 1 #Initial value of slope
c = -1 #Initial value of intercept
lr = 0.01 #Learning Rate
delta_m = 1 #Initialising Δm
delta_c = 1 #Initialising Δc
v_m = 0
v_c = 0
lam = 0.9
max_iters = 100 #Maximum number of iterations  
iters_count = 0 #Counting Iterations


def deriv(m_f, c_f, x, y):
    m_deriv = -1*(y-m_f*x-c_f)*x
    c_deriv = -1*(y-m_f*x-c_f)
    return m_deriv, c_deriv  


while iters_count < max_iters:
    print(x_train.shape[0])
    for i in range(x_train.shape[0]):
        delta_m, delta_c = deriv(m, c, x_train, y_train)
        v_m = lam * v_m - lr * delta_m
        v_c = lam * v_c - lr * delta_c
    m += v_m
    c += v_c
    iters_count += 1
    print(f"Iteration: {iters_count}\tValue of m: {m}, \tValue of c: {c}")
# Out:
# 1944
# Iteration: 1	Value of m: [1.14386657 1.00713216 0.97389214 ... 0.90657144 0.99770483 1.04708318], 	Value of c: [-0.7966853  -0.93809313 -0.92302607 ... -0.88958983 -0.9255895
#  -0.89674679]
# 1944
# Iteration: 2	Value of m: [1.26614301 1.01354164 0.95069542 ... 0.82917566 0.9956394  1.08847903], 	Value of c: [-0.62388214 -0.88245911 -0.85463505 ... -0.79812656 -0.85862714
#  -0.80596588]
# 1944
# Iteration: 3	Value of m: [1.37006935 1.01930166 0.93008523 ... 0.76506135 0.99378071 1.12487453], 	Value of c: [-0.47701164 -0.83246234 -0.79386991 ... -0.72235881 -0.79836738
#  -0.7261507 ]
# 1944
# Iteration: 4	Value of m: [1.45839942 1.02447804 0.91177317 ... 0.71194935 0.99210806 1.1568737 ], 	Value of c: [-0.35218208 -0.7875316  -0.73988034 ... -0.65959315 -0.74413933
#  -0.65597666]
# 1944
# Iteration: 5	Value of m: [1.53347374 1.02912991 0.89550297 ... 0.66795162 0.99060284 1.18500758], 	Value of c: [-0.24608575 -0.74715358 -0.69191083 ... -0.60759838 -0.69533924
#  -0.59427918]
#  -0.14521255]
# 1944
# Iteration: 95	Value of m: [1.95865951 1.07038462 0.76586067 ... 0.45555925 0.97707117 1.38978098], 	Value of c: [ 0.35479406 -0.38906435 -0.30968574 ... -0.35660149 -0.25663541
#  -0.14521198]
# 1944
# Iteration: 96	Value of m: [1.95865954 1.0703849  0.76586033 ... 0.45555925 0.97707107 1.38978121], 	Value of c: [ 0.3547941  -0.38906193 -0.30968472 ... -0.35660148 -0.25663209
#  -0.14521147]
# 1944
# Iteration: 97	Value of m: [1.95865956 1.07038515 0.76586002 ... 0.45555925 0.97707097 1.38978142], 	Value of c: [ 0.35479414 -0.38905976 -0.30968381 ... -0.35660148 -0.25662911
#  -0.14521103]
# 1944
# Iteration: 98	Value of m: [1.95865958 1.07038537 0.76585975 ... 0.45555925 0.97707089 1.38978159], 	Value of c: [ 0.35479417 -0.3890578  -0.30968301 ... -0.35660148 -0.25662643
#  -0.14521064]
# 1944
# Iteration: 99	Value of m: [1.9586596  1.07038558 0.76585951 ... 0.45555925 0.97707082 1.38978175], 	Value of c: [ 0.35479419 -0.38905604 -0.30968229 ... -0.35660148 -0.25662401
#  -0.1452103 ]
# 1944
# Iteration: 100	Value of m: [1.95865961 1.07038576 0.76585929 ... 0.45555925 0.97707075 1.38978189], 	Value of c: [ 0.35479421 -0.38905447 -0.30968166 ... -0.35660148 -0.25662184
#  -0.14521   ]

# %%
print(f"\nThe local minima occurs at: {m}, {c}")
# Out:
# The local minima occurs at: [1.95865961 1.07038576 0.76585929 ... 0.45555925 0.97707075 1.38978189], [ 0.35479421 -0.38905447 -0.30968166 ... -0.35660148 -0.25662184
#  -0.14521   ]

# %%
import numpy as np
y_pred_train = []
for i in x_train:
    y_p_tr = (m * i) + c
y_pred_train.append(y_p_tr)
y_pred_train = y_pred_train
print(y_pred_train)
print(y_train)
# Out:
# [array([ 1.2479376 ,  0.09903849,  0.03954807, ..., -0.14886772,
#         0.18891973,  0.48852672])]
# [ 1.74075238 -0.26572338 -0.56943854 ... -0.74209353 -0.28673971
#   0.48852937]

# %%
y_pred_test = []
for i in x_test:
    y_p_te = (m * i) + c
y_pred_test.append(y_p_te)
y_pred_test = np.array(y_pred_test)

# %%
import math
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error


#Training Accuracies
mse = math.sqrt(mean_squared_error(y_train, y_pred_train)) 
print('Root mean square error', mse) 
mse = (mean_squared_error(y_train, y_pred_train)) 
print('Mean square error', mse) 
mae=mean_absolute_error(y_train, y_pred_train)
print('Mean absolute error', mae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5ace8b7c15d6> in <module>
#       5
#       6 #Training Accuracies
# ----> 7 mse = math.sqrt(mean_squared_error(y_train, y_pred_train))
#       8 print('Root mean square error', mse)
#       9 mse = (mean_squared_error(y_train, y_pred_train))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [1944, 1]
